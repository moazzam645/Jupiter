# %% [markdown]
# Arrays
#
# 1D Array

# %%
import numpy as np

# %%
a= np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
b= np.zeros(3)

print(b)
# Out:
# [0. 0. 0.]

# %%
c=np.ones(4)
print(c)
# Out:
# [1. 1. 1. 1.]

# %%
d= np.empty(3)
print(d)
# Out:
# [0. 0. 0.]

# %%
e= np.arange(5)
print(a)
# Out:
# [1 2 3 4 5]

# %%
f= np.arange(2,10)
print(f)
# Out:
# [2 3 4 5 6 7 8 9]

# %%
g= np.arange(2,15,2)
print(g)
# Out:
# [ 2  4  6  8 10 12 14]

# %%
h= np.linspace(1,15,num=3)

print(h)
# Out:
# [ 1.  8. 15.]

# %%
i=np.ones(5, dtype=np.int8)
print(i)
# Out:
# [1 1 1 1 1]
