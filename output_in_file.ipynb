# %% [markdown]
# file ouptput

# %%
with open("./outputs/print_to_file .txt","w") as file:
    print("hello file handling!",file=file)

    #use ./ use to go next folder and ../ used to go previous folder
