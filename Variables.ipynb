# %% [markdown]
# # Vaiables

# %%
age=26
print ("I am  ",age," years old")

# %%
print (type( age),age)

# %%
print ("I am  ",age," years old")

# %% [markdown]
# #List

# %%
number= [11,22,33,44,55]
number[1]="ch"

# %%
print(number[1])

# %% [markdown]
# tuple

# %%
prices=(10,20,30,40,50,"xyz")
#prices(0)==66

# %%
print(prices)

# %%
person={"name":"Ali","age":20,
        "name":"Ahmed","age":21,"name":"Asad","age":22
        
        }

print(person["age"])

# %% [markdown]
# Sets

# %%
numbers={5,4,3,4,9,"a"}
#numbers[0]==55
print(numbers)

# %%
result=None

# %%
complex_v= 3+4j

print(complex_v)

# %%
#num=10
#num2= str(num)
text="abcbca"
numb3= set(text)

name="55"
con= int(name)
print(name,con)

# %%
number= " "
conver=bool(number)
numb=None
numb2=bool(numb)

print(number,conver,numb,numb2)

# %%
user_input=3.14
print("Enter your input /n")
#value= eval(user_input)
print(user_input,type(user_input))

#print(user_input,type(user_input),value)

# %% [markdown]
# Sequences

# %%
counting=[11,2,37,4,5]

count2=[6,7,8]

combined= counting+count2

print(combined)
print(1 in count2)

print(2 in counting)

print(7 not in counting)

# %% [markdown]
# Repition in sequences

# %%
list=[1,5,9]

print(list *2)

# %% [markdown]
# Negative Indexing

# %%
list=[11,22,33,44,55]

print(list[-1])
print(list)
print(list[1])

# %% [markdown]
# Matrix

# %%
matrix=[
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

print(matrix[0][2])
print(matrix[1][1])

# %% [markdown]
# Range/ Slicing

# %%
numbers=[1,2,3,4,5]

print(numbers[0:3])
print(numbers[-3:-1])

print(numbers[::2])

print(numbers[::1])

print(numbers[::3])

# %% [markdown]
# List Range
