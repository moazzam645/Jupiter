# %% [markdown]
# importing libraties Libraries

# %%
# !pip install openpyxl

# %%
import pandas as pd 
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.head()

# %%
df.to_excel('./dataframes/titanic.xlsx',index=False)

# %% [markdown]
# #Importing Dataset

# %%
df_titanic= pd.read_excel('./dataframes/titanic.xlsx')
