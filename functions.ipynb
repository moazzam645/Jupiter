# %% [markdown]
# Functions

# %%
def addition(a,b):
    add=a+b
    print(add)

# %%
x=7
y=5

addition(x,y)

# %%
def mean(numbers):
    return round( sum(numbers)/len(numbers),2)

# %%
prices=[15,285,306,85,1507]
mean(prices)
# Out:
# 439.6
